# %% [markdown]
# # Step 1 : Data Preparation

# %% [markdown]
# ### Goals : Decide Team Position
#
# ### Related Column :
# 0. team_position
# 1. overall
# 2. potential
# 3. pace
# 4. shooting
# 5. passing
# 6. dribbling
# 7. defending
# 8. physic
# 9. gk_diving
# 10. gk_handling
# 11. gk_kicking
# 12. gk_reflexes
# 13. gk_speed
# 14. gk_positioning
# 15. attacking_crossing
# 16. attacking_finishing
# 17. attacking_heading_accuracy
# 18. attacking_short_passing
# 19. attacking_volleys
# 20. skill_dribbling
# 21. skill_curve
# 22. skill_fk_accuracy
# 23. skill_long_passing
# 24. skill_ball_control
# 25. movement_acceleration
# 26. movement_sprint_speed
# 27. movement_agility
# 28. movement_reactions
# 29. movement_balance
# 30. power_shot_power
# 31. power_jumping
# 32. power_stamina
# 33. power_strength
# 34. power_long_shots
# 35. mentality_aggression
# 36. mentality_interceptions
# 37. mentality_positioning
# 38. mentality_vision
# 39. mentality_penalties
# 40. mentality_composure
# 41. defending_marking
# 42. defending_standing_tackle
# 43. defending_sliding_tackle
# 44. goalkeeping_diving
# 45. goalkeeping_handling
# 46. goalkeeping_kicking
# 47. goalkeeping_positioning
# 48. goalkeeping_reflexes

# %%
# import some libs
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read all data from dataset fifa 
df_path = 'Data/fifa20.csv'
df = pd.read_csv(df_path)
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
# check header of data frame
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
# get all team position possibilities
print(df['team_position'].unique())
print(len(df['team_position'].unique()))
# Out:
# ['RW' 'LW' 'CAM' 'GK' 'RCM' 'LCB' 'ST' 'CDM' 'LDM' 'RM' 'RCB' 'LCM' 'LM'
#  'CF' 'SUB' 'LB' 'LS' 'RB' 'RDM' 'RES' 'RAM' 'RS' 'RF' 'CM' 'CB' 'LF'
#  'LAM' nan 'RWB' 'LWB']
# 30

# %% [markdown]
# Dari data di atas diketahui terdapat 29 jenis posisi ( exclude NaN )

# %%
# check null at every column
heatmap = sns.heatmap(df.isna())

# %% [markdown]
# dari grafik heat map diatas dapat diketahui colum yang banyak terdapat null, sehingga jika tidak dibutuhkan maka tidak perlu digunakan.

# %%
# get important columns only
list_columns = [
    "team_position","overall","potential","pace","shooting","passing","dribbling","defending","physic",
    "gk_diving","gk_handling","gk_kicking","gk_reflexes","gk_speed","gk_positioning","attacking_crossing",
    "attacking_finishing","attacking_heading_accuracy","attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve",
    "skill_fk_accuracy","skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed","movement_agility",
    "movement_reactions","movement_balance","power_shot_power","power_jumping","power_stamina","power_strength","power_long_shots","mentality_aggression",
    "mentality_interceptions","mentality_positioning","mentality_vision","mentality_penalties","mentality_composure","defending_marking","defending_standing_tackle",
    "defending_sliding_tackle","goalkeeping_diving","goalkeeping_handling","goalkeeping_kicking","goalkeeping_positioning", "goalkeeping_reflexes"]
df = df[list_columns]
df.head()
# Out:
#   team_position  overall  potential  pace  shooting  passing  dribbling  \
# 0            RW       94         94  87.0      92.0     92.0       96.0
# 1            LW       93         93  90.0      93.0     82.0       89.0
# 2           CAM       92         92  91.0      85.0     87.0       95.0
# 3            GK       91         93   NaN       NaN      NaN        NaN
# 4            LW       91         91  91.0      83.0     86.0       94.0
#
#    defending  physic  gk_diving  ...  mentality_penalties  \
# 0       39.0    66.0        NaN  ...                   75
# 1       35.0    78.0        NaN  ...                   85
# 2       32.0    58.0        NaN  ...                   90
# 3        NaN     NaN       87.0  ...                   11
# 4       35.0    66.0        NaN  ...                   88
#
#    mentality_composure  defending_marking  defending_standing_tackle  \
# 0                   96                 33                         37
# ...

# %% [markdown]
# Kolom yang akan diambil digunakan untuk menjadi 2 jenis feature.
#
# Feature pertama terdiri dari statistik utama yaitu
# `"pace","shooting","passing","dribbling","defending","physic","gk_diving","gk_handling","gk_kicking","gk_reflexes","gk_speed","gk_positioning"`
#
# dan feature kedua terdiri dari statistik pelengkap yaitu
# `"attacking_crossing","attacking_finishing","attacking_heading_accuracy","attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy","skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed","movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping","power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions","mentality_positioning","mentality_vision","mentality_penalties","mentality_composure","defending_marking","defending_standing_tackle","defending_sliding_tackle","goalkeeping_diving","goalkeeping_handling","goalkeeping_kicking","goalkeeping_positioning", "goalkeeping_reflexes"`
#
# ![image.png](attachment:image.png)

# %%
# save as dataset to folder Data
df.to_csv("Data/dataset_fifa.csv", sep=';',index=False, encoding='utf-8')
